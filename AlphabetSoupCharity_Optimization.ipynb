# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns=(['EIN', 'NAME']),inplace=True)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = [i[0] for i in application_df['APPLICATION_TYPE'].value_counts().items() if i[1] < 528]

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
vc = application_df['CLASSIFICATION'].value_counts()
vc.loc[vc > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = [r for r in vc.loc[vc < 1883].index]

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)
application_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                       0
# 1       1   108590              1                       0
# 2       1     5000              0                       0
# 3       1     6692              1                       0
# 4       1   142590              1                       0
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                     1                     0                    0
# 1                     0                     0                    1
# 2                     0                     0                    0
# 3                     0                     0                    1
# 4                     0                     0                    1
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                    0                    0                    0  ...
# ...

# %% [markdown]
# ### Look for columns with skewed data that can be dropped

# %%
#for c in application_df.columns:
#  print(application_df[c].value_counts())
# Out:
# 1    34294
# 0        5
# Name: STATUS, dtype: int64
# 5000        25398
# 10478           3
# 15583           3
# 63981           3
# 6725            3
#             ...
# 5371754         1
# 30060           1
# 43091152        1
# 18683           1
# 36500179        1
# Name: ASK_AMT, Length: 8747, dtype: int64
# 0    34023
# 1      276
# Name: APPLICATION_TYPE_Other, dtype: int64
# 0    33771
# 1      528
# Name: APPLICATION_TYPE_T10, dtype: int64
# 0    33234
# 1     1065
# Name: APPLICATION_TYPE_T19, dtype: int64
# 1    27037
# 0     7262
# Name: APPLICATION_TYPE_T3, dtype: int64
# 0    32757
# 1     1542
# Name: APPLICATION_TYPE_T4, dtype: int64
# 0    33126
# 1     1173
# Name: APPLICATION_TYPE_T5, dtype: int64
# 0    33083
# 1     1216
# Name: APPLICATION_TYPE_T6, dtype: int64
# 0    33574
# 1      725
# Name: APPLICATION_TYPE_T7, dtype: int64
# 0    33562
# 1      737
# Name: APPLICATION_TYPE_T8, dtype: int64
# 0    18594
# 1    15705
# ...

# %% [markdown]
# ### Run 1 for 75% accuracy
# - Drop the columns USE_CASE_Other and AFFILIATION_Other from the application_df dataframe

# %%
# Split our preprocessed data into our features and target arrays
y = application_df['IS_SUCCESSFUL']
X = application_df.drop(columns=['IS_SUCCESSFUL', 'USE_CASE_Other', 'AFFILIATION_Other'])

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=41))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=30, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 80)                3360
#
#  dense_7 (Dense)             (None, 30)                2430
#
#  dense_8 (Dense)             (None, 1)                 31
#
# ...
# Total params: 5,821
# Trainable params: 5,821
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
mc = tf.keras.callbacks.ModelCheckpoint('AlphabetSoupCharity_weights_optimized.h5',
                                     save_weights_only=True, save_freq=5)
fit_model = nn.fit(X_train_scaled,y_train,epochs=100, callbacks=[mc])
# Out:
# Epoch 1/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5687 - accuracy: 0.7224
# Epoch 2/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5547 - accuracy: 0.7286
# Epoch 3/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5531 - accuracy: 0.7289
# Epoch 4/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5499 - accuracy: 0.7311
# Epoch 5/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5497 - accuracy: 0.7325
# Epoch 6/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5486 - accuracy: 0.7332
# Epoch 7/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5479 - accuracy: 0.7325
# Epoch 8/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5471 - accuracy: 0.7335
# Epoch 9/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5461 - accuracy: 0.7344
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5603 - accuracy: 0.7279 - 518ms/epoch - 2ms/step
# Loss: 0.5603266954421997, Accuracy: 0.7279300093650818

# %% [markdown]
# ### Run 2 for 75% accuracy
# - Double the units for layers 1 and 2 from 80/30 to 160/60

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=160, activation="relu", input_dim=41))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=60, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_12 (Dense)            (None, 160)               6720
#
#  dense_13 (Dense)            (None, 60)                9660
#
#  dense_14 (Dense)            (None, 1)                 61
#
# ...
# Total params: 16,441
# Trainable params: 16,441
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
mc = tf.keras.callbacks.ModelCheckpoint('AlphabetSoupCharity_weights_optimized.h5',
                                     save_weights_only=True, save_freq=5)
fit_model = nn.fit(X_train_scaled,y_train,epochs=100, callbacks=[mc])
# Out:
# Epoch 1/100
# 804/804 [==============================] - 7s 6ms/step - loss: 0.5691 - accuracy: 0.7244
# Epoch 2/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5565 - accuracy: 0.7289
# Epoch 3/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5523 - accuracy: 0.7303
# Epoch 4/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5508 - accuracy: 0.7298
# Epoch 5/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5498 - accuracy: 0.7334
# Epoch 6/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5492 - accuracy: 0.7327
# Epoch 7/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5481 - accuracy: 0.7327
# Epoch 8/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5471 - accuracy: 0.7336
# Epoch 9/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5472 - accuracy: 0.7336
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5652 - accuracy: 0.7291 - 493ms/epoch - 2ms/step
# Loss: 0.5651891827583313, Accuracy: 0.7290962338447571

# %% [markdown]
# ### Run 3 for 75% accuracy
# - Remove the second layer

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=41))

# Second hidden layer
#nn.add(tf.keras.layers.Dense(units=30, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_15 (Dense)            (None, 80)                3360
#
#  dense_16 (Dense)            (None, 1)                 81
#
# ...
# Total params: 3,441
# Trainable params: 3,441
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
mc = tf.keras.callbacks.ModelCheckpoint('AlphabetSoupCharity_weights_optimized.h5',
                                     save_weights_only=True, save_freq=5)
fit_model = nn.fit(X_train_scaled,y_train,epochs=100, callbacks=[mc])
# Out:
# Epoch 1/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5769 - accuracy: 0.7152
# Epoch 2/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5589 - accuracy: 0.7269
# Epoch 3/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5555 - accuracy: 0.7294
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5536 - accuracy: 0.7296
# Epoch 5/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5525 - accuracy: 0.7292
# Epoch 6/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5516 - accuracy: 0.7301
# Epoch 7/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5508 - accuracy: 0.7318
# Epoch 8/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5499 - accuracy: 0.7314
# Epoch 9/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5492 - accuracy: 0.7316
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5542 - accuracy: 0.7282 - 1s/epoch - 4ms/step
# Loss: 0.554207980632782, Accuracy: 0.7281632423400879

# %%
# Export our model to HDF5 file
nn.save('AlphabetSoupCharity_Optimized.h5', save_format='h5')
